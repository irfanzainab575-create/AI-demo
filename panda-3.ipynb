# %%
import numpy as np
import pandas as pd
cus_df=pd.read_csv("C:\Users\USER\Desktop\python\generic-food.csv")
cus_df.headO()
# Out:
#   Cell In[2], line 3
#     cus_df=pd.read_csv("C:\Users\USER\Desktop\python\generic-food.csv")
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
